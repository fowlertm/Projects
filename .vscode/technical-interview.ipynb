# %% [markdown]
# 1. Create a TicTacToe class with a data structure for your board with initial values, and create a method to pretty print the the board.
#
# 2. Now create a method to start the game, that carries out a basic game loop (asks the user for input to make a move, and then responds with the computer’s move^). For the moment, have the computer make any random move, and print the board after each move.
#
# 3. Implement validation for user moves, so that impossible^^ moves are not accepted.

# %%
import numpy as np

class TicTacToe:
    
    
    def __init__(self):
        self.occupied = set()
        self.board = ['1', '2', '3', '4', '5', '6', '7', '8', '9']
#         self.available = [y for x in self.board for y in x if y not in self.occupied]
        self.available = [x for x in self.board if x not in self.occupied]
        
    def get_user_move(self):
        user_move = input("Place an 'X' at the integer location you want.")
        if user_move not in '123456789' or user_move in self.occupied:
            self.get_user_move()
        return user_move
    
#     def update_available(self):
#         self.available = [y for x in self.board for y in x if y not in self.occupied] 
    
    def update_occupied(self):
        self.occupied.add(user_input)
        return self.occupied
    
    def get_computer_move(self, board, available):
        # When we get the AIs move, we need a way of checking the state of the board and 
        # biasing the computer towards expert play.
        
        # What does this entail? We have a 1D representation of the game board in the form of 
        # a list of strings, and we've written some fairly gross conditional architecture to 
        # determine winning. moves. What we want is to have the get_computer_move() method 
        # to take the string representing the board and search over it, looking for two kinds 
        # of moves: those that block a user's victory, and those that maximize the probability 
        # of the computer's victory. 
        
        # If the win_check() function weren't freshman-level code perhaps we could call it within
        # the get_computer_move() function, but as it stands the former just returns None if 
        # if no winning condition is met. So, we'll have to look elsewhere. 
        
        # The MVP would probably be to check for whether or not there are any strings of two 
        # 'X's, and make the computer's next move be to block the next move. God help me, but 
        # I can't think of any way to do this but with yet *more* if/elif/else statements. Actually,
        # maybe I can get a for loop to do it. 
        
        for i in range(len(self.board) - 2): # to prevent IndexOutOfRange
            if self.board[i] == self.board[i + 1] and self.board[i + 2] in self.available:
                computer_move = self.board[i + 2]
                print(computer_move)
            
        computer_move = np.random.choice(self.available, 1)[0]
         
        return str(computer_move)
    
    def pretty_print(self, board):
        return(str(board[:3]) + '\n' + str(board[3:6]) + '\n' + str(board[6:9]))
    
    def win_check(self, board):
        winner = ''
        if self.board[0] == self.board[1] == self.board[2] == 'X':
            winner = 'User'
        elif self.board[3] == self.board[4] == self.board[5] == 'X':
            winner = 'User'
        elif self.board[6] == self.board[7] == self.board[8] == 'X':
            winner = 'User'
        elif self.board[0] == self.board[3] == self.board[6] == 'X':
            winner = 'User'
        elif self.board[1] == self.board[4] == self.board[7] == 'X':
            winner = 'User'
        elif self.board[2] == self.board[5] == self.board[8] == 'X':
            winner = 'User'
        elif self.board[0] == self.board[4] == self.board[8] == 'X':
            winner = 'User'
        elif self.board[2] == self.board[4] == self.board[6] == 'X':
            winner = 'User'

        elif self.board[0] == self.board[1] == self.board[2] == 'O':
            winner = 'Computer'
        elif self.board[3] == self.board[4] == self.board[5] == 'O':
            winner = 'Computer'
        elif self.board[6] == self.board[7] == self.board[8] == 'O':
            winner = 'Computer'
        elif self.board[0] == self.board[3] == self.board[6] == 'O':
            winner = 'Computer'
        elif self.board[1] == self.board[4] == self.board[7] == 'O':
            winner = 'Computer'
        elif self.board[2] == self.board[5] == self.board[8] == 'O':
            winner = 'Computer'
        elif self.board[0] == self.board[4] == self.board[8] == 'O':
            winner = 'Computer'
        elif self.board[2] == self.board[4] == self.board[6] == 'O':
            winner = 'Computer'

        return winner
    
    def start(self):
        
#         print(self.board)
#         while not self.game_over():
        while not self.win_check(self.board):
    
            user_move = self.get_user_move()
            if user_move in self.available:
                self.available.remove(user_move)
            self.occupied.add(user_move)
            # Hey, at least it's pythonic. 
            self.board = ['X' if char == user_move else char for char in self.board]
            self.win_check(self.board)
            
            if len(self.available) > 1:
                comp_move = self.get_computer_move(self.board, self.available)
            if comp_move in self.available:
                self.available.remove(comp_move)
            self.occupied.add(comp_move)
            self.board = ['O' if char == comp_move else char for char in self.board]
            self.win_check(self.board)

            print(self.pretty_print(self.board)) # Define a pretty print function.
        return self.win_check(self.board)
    
    def game_over(self):
        return len(self.available) == 0

# %%
game1 = TicTacToe()
game1.start()
# Out:
# Place an 'X' at the integer location you want.1
# ['X', '2', '3']
# ['O', '5', '6']
# ['7', '8', '9']
# Place an 'X' at the integer location you want.2
# 3
# ['X', 'X', '3']
# ['O', 'O', '6']
# ['7', '8', '9']
# Place an 'X' at the integer location you want.7
# 3
# 6
# ['X', 'X', '3']
# ['O', 'O', 'O']
# ['X', '8', '9']
# 'Computer'

# %% [markdown]
# 5(a) Implement an AI using a brute force.
#
# 5(b) Implement an AI using a standard algorithm / tree data structure.
#
# 5(c) Implement an AI using Keras/Tensorflow
